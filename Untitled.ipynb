# %%
# app.py

import streamlit as st
import numpy as np
import cv2
import torch
from PIL import Image
import torchvision.transforms as transforms

# Load your trained models (replace with your model loading code)
nested_unet_model = torch.load('path/to/nested_unet_weights.pth')
attention_unet_model = torch.load('path/to/attention_unet_weights.pth')

# Set models to evaluation mode
nested_unet_model.eval()
attention_unet_model.eval()

# Define preprocessing function
def preprocess_image(image):
    image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    image = cv2.resize(image, (256, 256))  # Resize based on your model's input size
    image = transforms.ToTensor()(image)
    image = image.unsqueeze(0)  # Add batch dimension
    return image

# Define function for segmentation
def segment_image(model, image_tensor):
    with torch.no_grad():
        output = model(image_tensor)
    return output.argmax(dim=1).squeeze().numpy()

# Streamlit UI
st.title("Brain MRI Metastasis Segmentation")
st.write("Upload an MRI image to segment metastasis.")

uploaded_file = st.file_uploader("Choose an MRI image...", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # Load and preprocess image
    image = Image.open(uploaded_file)
    st.image(image, caption='Uploaded Image', use_column_width=True)

    # Preprocess the image
    image_tensor = preprocess_image(image)

    # Segment using Nested U-Net
    st.write("Segmenting using Nested U-Net...")
    nested_unet_output = segment_image(nested_unet_model, image_tensor)
    st.image(nested_unet_output, caption='Nested U-Net Segmentation', use_column_width=True, clamp=True)

    # Segment using Attention U-Net
    st.write("Segmenting using Attention U-Net...")
    attention_unet_output = segment_image(attention_unet_model, image_tensor)
    st.image(attention_unet_output, caption='Attention U-Net Segmentation', use_column_width=True, clamp=True)

# Run the app with: streamlit run app.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # app.py
# ----> 3 import streamlit as st
#       4 import numpy as np
#       5 import cv2
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install streamlit
# Out:
#   Cell In[2], line 1
#     pip install streamlit
#         ^
# SyntaxError: invalid syntax

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (1.8.2)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (24.1)
# Collecting pandas<3,>=1.3.0 (from streamlit)
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (4.25.5)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (13.8.1)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from streamlit) (6.4.1)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.2-py3-none-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.8.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3,>=1.3.0->streamlit)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3,>=1.3.0->streamlit)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ----------------- ---------------------- 3.9/8.7 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 20.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 18.7 MB/s eta 0:00:00
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    --------------------------------------- 658.1/658.1 kB 12.8 MB/s eta 0:00:00
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.5 MB 21.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 18.5 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp312-cp312-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ----- ---------------------------------- 3.7/25.1 MB 18.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.3/25.1 MB 17.4 MB/s eta 0:00:02
#    ------------------ --------------------- 11.5/25.1 MB 19.0 MB/s eta 0:00:01
#    ------------------------- -------------- 16.3/25.1 MB 19.7 MB/s eta 0:00:01
#    -------------------------------- ------- 20.2/25.1 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  24.6/25.1 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 18.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------------- -------------- 4.5/6.9 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 19.3 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading narwhals-1.8.4-py3-none-any.whl (174 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: pytz, watchdog, tzdata, toml, tenacity, smmap, pyarrow, narwhals, cachetools, pydeck, pandas, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.4.1 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 narwhals-1.8.4 pandas-2.2.3 pyarrow-17.0.0 pydeck-0.9.1 pytz-2024.2 smmap-5.0.1 streamlit-1.38.0 tenacity-8.5.0 toml-0.10.2 tzdata-2024.2 watchdog-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# app.py

import streamlit as st
import numpy as np
import cv2
import torch
from PIL import Image
import torchvision.transforms as transforms

# Load your trained models (replace with your model loading code)
nested_unet_model = torch.load('path/to/nested_unet_weights.pth')
attention_unet_model = torch.load('path/to/attention_unet_weights.pth')

# Set models to evaluation mode
nested_unet_model.eval()
attention_unet_model.eval()

# Define preprocessing function
def preprocess_image(image):
    image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    image = cv2.resize(image, (256, 256))  # Resize based on your model's input size
    image = transforms.ToTensor()(image)
    image = image.unsqueeze(0)  # Add batch dimension
    return image

# Define function for segmentation
def segment_image(model, image_tensor):
    with torch.no_grad():
        output = model(image_tensor)
    return output.argmax(dim=1).squeeze().numpy()

# Streamlit UI
st.title("Brain MRI Metastasis Segmentation")
st.write("Upload an MRI image to segment metastasis.")

uploaded_file = st.file_uploader("Choose an MRI image...", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # Load and preprocess image
    image = Image.open(uploaded_file)
    st.image(image, caption='Uploaded Image', use_column_width=True)

    # Preprocess the image
    image_tensor = preprocess_image(image)

    # Segment using Nested U-Net
    st.write("Segmenting using Nested U-Net...")
    nested_unet_output = segment_image(nested_unet_model, image_tensor)
    st.image(nested_unet_output, caption='Nested U-Net Segmentation', use_column_width=True, clamp=True)

    # Segment using Attention U-Net
    st.write("Segmenting using Attention U-Net...")
    attention_unet_output = segment_image(attention_unet_model, image_tensor)
    st.image(attention_unet_output, caption='Attention U-Net Segmentation', use_column_width=True, clamp=True)

# Run the app with: streamlit run app.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       4 import numpy as np
#       5 import cv2
# ----> 6 import torch
#       7 from PIL import Image
#       8 import torchvision.transforms as transforms
#
# ModuleNotFoundError: No module named 'torch'

# %%
streamlit run app.py
